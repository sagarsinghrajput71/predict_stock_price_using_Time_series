# %%
import pandas as pd
import numpy as np
import matplotlib as plt
import seaborn as sns

# %%
df=pd.read_csv('D:\python\Predict stock market/BAJFINANCE.csv')
df.head()
# Out:
#          Date      Symbol Series  Prev Close   Open   High   Low   Last  \
# 0  2000-01-03  BAJAUTOFIN     EQ       46.95  49.45  50.75  46.5  50.75
# 1  2000-01-04  BAJAUTOFIN     EQ       50.75  53.20  53.20  47.9  48.00
# 2  2000-01-05  BAJAUTOFIN     EQ       48.10  46.55  47.40  44.6  44.60
# 3  2000-01-06  BAJAUTOFIN     EQ       44.60  43.50  46.00  42.1  46.00
# 4  2000-01-07  BAJAUTOFIN     EQ       45.25  48.00  48.00  42.0  42.90
#
#    Close   VWAP  Volume      Turnover  Trades  Deliverable Volume  %Deliverble
# 0  50.75  50.05    7600  3.803800e+10     NaN                 NaN          NaN
# 1  48.10  48.56    5000  2.428000e+10     NaN                 NaN          NaN
# 2  44.60  45.47    3500  1.591450e+10     NaN                 NaN          NaN
# 3  45.25  44.43    6200  2.754750e+10     NaN                 NaN          NaN
# 4  42.90  44.44    3500  1.555550e+10     NaN                 NaN          NaN

# %%
df.set_index('Date',inplace=True)

# %%
df['VWAP'].plot(
)

# %%
df.shape
# Out:
# (5070, 14)

# %%
df.isnull().sum(
)
# Out:
# Symbol                   0
# Series                   0
# Prev Close               0
# Open                     0
# High                     0
# Low                      0
# Last                     0
# Close                    0
# VWAP                     0
# Volume                   0
# Turnover                 0
# Trades                2779
# Deliverable Volume     446
# %Deliverble            446
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
df.shape
# Out:
# (2291, 14)

# %%
df.isnull().sum()
# Out:
# Symbol                0
# Series                0
# Prev Close            0
# Open                  0
# High                  0
# Low                   0
# Last                  0
# Close                 0
# VWAP                  0
# Volume                0
# Turnover              0
# Trades                0
# Deliverable Volume    0
# %Deliverble           0
# dtype: int64

# %%
df.dtypes
# Out:
# Symbol                 object
# Series                 object
# Prev Close            float64
# Open                  float64
# High                  float64
# Low                   float64
# Last                  float64
# Close                 float64
# VWAP                  float64
# Volume                  int64
# Turnover              float64
# Trades                float64
# Deliverable Volume    float64
# %Deliverble           float64
# dtype: object

# %%
data=df.copy(
)

# %%
data.dtypes
# Out:
# Symbol                 object
# Series                 object
# Prev Close            float64
# Open                  float64
# High                  float64
# Low                   float64
# Last                  float64
# Close                 float64
# VWAP                  float64
# Volume                  int64
# Turnover              float64
# Trades                float64
# Deliverable Volume    float64
# %Deliverble           float64
# dtype: object

# %%
data.columns
# Out:
# Index(['Symbol', 'Series', 'Prev Close', 'Open', 'High', 'Low', 'Last',
#        'Close', 'VWAP', 'Volume', 'Turnover', 'Trades', 'Deliverable Volume',
#        '%Deliverble'],
#       dtype='object')

# %%
lag_features=['High','Low','Volume','Turnover','Trades']
window1=3
window2=7

# %%
for feature in lag_features:
    data[feature+'rolling_mean_3']=data[feature].rolling(window=window1).mean()
    data[feature+'rolling_mean_7']=data[feature].rolling(window=window2).mean()

# %%
for feature in lag_features:
    data[feature+'rolling_std_3']=data[feature].rolling(window=window1).std()
    data[feature+'rolling_std_7']=data[feature].rolling(window=window2).std()

# %%
data.head()
# Out:
#                 Symbol Series  Prev Close    Open    High     Low    Last  \
# Date
# 2011-06-01  BAJFINANCE     EQ      616.70  617.00  636.50  616.00  627.00
# 2011-06-02  BAJFINANCE     EQ      631.85  625.00  638.90  620.00  634.00
# 2011-06-03  BAJFINANCE     EQ      633.45  625.15  637.80  620.00  623.00
# 2011-06-06  BAJFINANCE     EQ      625.00  620.00  641.00  611.35  611.35
# 2011-06-07  BAJFINANCE     EQ      614.00  604.00  623.95  604.00  619.90
#
#              Close    VWAP  Volume  ...  Highrolling_std_3  Highrolling_std_7  \
# Date                                ...
# 2011-06-01  631.85  627.01    6894  ...                NaN                NaN
# 2011-06-02  633.45  636.04    2769  ...                NaN                NaN
# 2011-06-03  625.00  625.09   51427  ...           1.201388                NaN
# 2011-06-06  614.00  616.03    5446  ...           1.625833                NaN
# 2011-06-07  619.15  617.73    5991  ...           9.062422                NaN
#
#             Lowrolling_std_3  Lowrolling_std_7  Volumerolling_std_3  \
# Date
# 2011-06-01               NaN               NaN                  NaN
# 2011-06-02               NaN               NaN                  NaN
# 2011-06-03          2.309401               NaN         26980.871860
# 2011-06-06          4.994080               NaN         27352.695339
# 2011-06-07          8.008797               NaN         26391.221653
#
#             Volumerolling_std_7  Turnoverrolling_std_3  Turnoverrolling_std_7  \
# Date
# 2011-06-01                  NaN                    NaN                    NaN
# 2011-06-02                  NaN                    NaN                    NaN
# 2011-06-03                  NaN           1.685217e+12                    NaN
# 2011-06-06                  NaN           1.710136e+12                    NaN
# 2011-06-07                  NaN           1.652377e+12                    NaN
#
#             Tradesrolling_std_3  Tradesrolling_std_7
# Date
# 2011-06-01                  NaN                  NaN
# 2011-06-02                  NaN                  NaN
# 2011-06-03           670.500559                  NaN
# 2011-06-06           148.769396                  NaN
# 2011-06-07            78.270897                  NaN
#
# [5 rows x 34 columns]

# %%
data.columns
# Out:
# Index(['Symbol', 'Series', 'Prev Close', 'Open', 'High', 'Low', 'Last',
#        'Close', 'VWAP', 'Volume', 'Turnover', 'Trades', 'Deliverable Volume',
#        '%Deliverble', 'Highrolling_mean_3', 'Highrolling_mean_7',
#        'Lowrolling_mean_3', 'Lowrolling_mean_7', 'Volumerolling_mean_3',
#        'Volumerolling_mean_7', 'Turnoverrolling_mean_3',
#        'Turnoverrolling_mean_7', 'Tradesrolling_mean_3',
#        'Tradesrolling_mean_7', 'Highrolling_std_3', 'Highrolling_std_7',
#        'Lowrolling_std_3', 'Lowrolling_std_7', 'Volumerolling_std_3',
#        'Volumerolling_std_7', 'Turnoverrolling_std_3', 'Turnoverrolling_std_7',
#        'Tradesrolling_std_3', 'Tradesrolling_std_7'],
#       dtype='object')

# %%
data.shape
# Out:
# (2291, 34)

# %%
data.isnull().sum()
# Out:
# Symbol                    0
# Series                    0
# Prev Close                0
# Open                      0
# High                      0
# Low                       0
# Last                      0
# Close                     0
# VWAP                      0
# Volume                    0
# Turnover                  0
# Trades                    0
# Deliverable Volume        0
# %Deliverble               0
# Highrolling_mean_3        2
# Highrolling_mean_7        6
# Lowrolling_mean_3         2
# Lowrolling_mean_7         6
# Volumerolling_mean_3      2
# Volumerolling_mean_7      6
# Turnoverrolling_mean_3    2
# Turnoverrolling_mean_7    6
# Tradesrolling_mean_3      2
# Tradesrolling_mean_7      6
# Highrolling_std_3         2
# Highrolling_std_7         6
# Lowrolling_std_3          2
# Lowrolling_std_7          6
# Volumerolling_std_3       2
# Volumerolling_std_7       6
# Turnoverrolling_std_3     2
# Turnoverrolling_std_7     6
# Tradesrolling_std_3       2
# Tradesrolling_std_7       6
# dtype: int64

# %%
data.dropna(inplace=True)

# %%
data.columns
# Out:
# Index(['Symbol', 'Series', 'Prev Close', 'Open', 'High', 'Low', 'Last',
#        'Close', 'VWAP', 'Volume', 'Turnover', 'Trades', 'Deliverable Volume',
#        '%Deliverble', 'Highrolling_mean_3', 'Highrolling_mean_7',
#        'Lowrolling_mean_3', 'Lowrolling_mean_7', 'Volumerolling_mean_3',
#        'Volumerolling_mean_7', 'Turnoverrolling_mean_3',
#        'Turnoverrolling_mean_7', 'Tradesrolling_mean_3',
#        'Tradesrolling_mean_7', 'Highrolling_std_3', 'Highrolling_std_7',
#        'Lowrolling_std_3', 'Lowrolling_std_7', 'Volumerolling_std_3',
#        'Volumerolling_std_7', 'Turnoverrolling_std_3', 'Turnoverrolling_std_7',
#        'Tradesrolling_std_3', 'Tradesrolling_std_7'],
#       dtype='object')

# %%
ind_features=['Highrolling_mean_3', 'Highrolling_mean_7',
       'Lowrolling_mean_3', 'Lowrolling_mean_7', 'Volumerolling_mean_3',
       'Volumerolling_mean_7', 'Turnoverrolling_mean_3',
       'Turnoverrolling_mean_7', 'Tradesrolling_mean_3',
       'Tradesrolling_mean_7', 'Highrolling_std_3', 'Highrolling_std_7',
       'Lowrolling_std_3', 'Lowrolling_std_7', 'Volumerolling_std_3',
       'Volumerolling_std_7', 'Turnoverrolling_std_3', 'Turnoverrolling_std_7',
       'Tradesrolling_std_3', 'Tradesrolling_std_7'
             ]

# %%
training_data=data[0:1800]
test_data=data[1800:]

# %%
training_data
# Out:
#                 Symbol Series  Prev Close     Open     High      Low     Last  \
# Date
# 2011-06-09  BAJFINANCE     EQ      635.60   639.80   647.00   630.00   630.00
# 2011-06-10  BAJFINANCE     EQ      631.10   641.85   648.25   618.55   621.10
# 2011-06-13  BAJFINANCE     EQ      622.20   616.00   627.85   616.00   622.75
# 2011-06-14  BAJFINANCE     EQ      624.95   625.00   628.95   619.95   621.20
# 2011-06-15  BAJFINANCE     EQ      622.10   612.00   623.00   598.10   605.00
# ...                ...    ...         ...      ...      ...      ...      ...
# 2018-09-04  BAJFINANCE     EQ     2724.05  2724.00  2777.65  2683.50  2748.00
# 2018-09-05  BAJFINANCE     EQ     2746.30  2740.15  2764.80  2668.00  2704.45
# 2018-09-06  BAJFINANCE     EQ     2716.90  2729.00  2731.50  2671.40  2672.20
# 2018-09-07  BAJFINANCE     EQ     2684.10  2698.40  2751.40  2672.60  2745.00
# 2018-09-10  BAJFINANCE     EQ     2744.20  2732.00  2738.00  2596.00  2607.60
#
#               Close     VWAP   Volume  ...  Highrolling_std_3  \
# Date                                   ...
# 2011-06-09   631.10   638.27    31252  ...          12.769789
# 2011-06-10   622.20   634.16    30885  ...           1.639360
# 2011-06-13   624.95   622.92     3981  ...          11.434196
# 2011-06-14   622.10   625.35     5597  ...          11.473593
# 2011-06-15   601.70   606.90    12590  ...           3.165833
# ...             ...      ...      ...  ...                ...
# 2018-09-04  2746.30  2726.23  2606992  ...          88.954937
# 2018-09-05  2716.90  2712.53  1728455  ...          63.129081
# 2018-09-06  2684.10  2695.89  1147879  ...          23.818183
# 2018-09-07  2744.20  2716.32  1264436  ...          16.755397
# 2018-09-10  2615.65  2655.39  1570179  ...          10.147413
#
#             Highrolling_std_7  Lowrolling_std_3  Lowrolling_std_7  \
# Date
# 2011-06-09           7.494911         15.011107          9.410145
# 2011-06-10           8.227994         13.030765          9.501961
# 2011-06-13           9.497080          7.456597          9.298317
# 2011-06-14          10.198891          2.002707          9.293713
# 2011-06-15          11.352292         11.643560         11.262712
# ...                       ...               ...               ...
# 2018-09-04          79.489416         83.341306        107.041856
# 2018-09-05         100.594924         24.113551        119.854378
# 2018-09-06         113.135709          8.146778        118.187686
# 2018-09-07         106.101111          2.386071        100.988340
# 2018-09-10          84.670766         43.882722         74.650851
#
#             Volumerolling_std_3  Volumerolling_std_7  Turnoverrolling_std_3  \
# Date
# 2011-06-09         13497.047986         18373.894011           8.665128e+11
# 2011-06-10          2434.970705         18047.331029           1.579562e+11
# 2011-06-13         15640.051929         17835.642665           9.982094e+11
# 2011-06-14         15088.183102         13139.472184           9.595224e+11
# 2020-08-26         116.819954        115.027609        100.638138
# 2020-08-27         122.216500         62.320569        111.614377
# 2020-08-28         124.544624         17.407781        119.736752
# 2020-08-31         112.033479         82.473819        103.463256
#
#             Volumerolling_std_3  Volumerolling_std_7  Turnoverrolling_std_3  \
# Date
# 2018-09-11         1.130645e+06         8.164109e+05           2.905375e+14
# 2018-09-12         9.025933e+05         8.351259e+05           2.325644e+14
# 2018-09-14         7.836553e+05         8.007301e+05           2.018671e+14
# 2018-09-17         6.335337e+05         8.189293e+05           1.593010e+14
# 2018-09-18         1.979536e+05         7.800295e+05           5.634743e+13
# ...                         ...                  ...                    ...
# 2020-08-25         3.613401e+06         2.348888e+06           1.315344e+15
# 2020-08-26         1.987080e+06         2.403611e+06           7.237865e+14
# 2020-08-27         2.641848e+06         2.408580e+06           9.306171e+14
# 2020-08-28         1.302259e+06         2.404277e+06           4.837586e+14
# 2020-08-31         2.373052e+06         2.517269e+06           8.448489e+14
#
#             Turnoverrolling_std_7  Tradesrolling_std_3  Tradesrolling_std_7
# Date
# 2018-09-11           2.170264e+14         40756.099335         32012.681782
# 2018-09-12           2.156391e+14         31297.267202         34656.587966
# 2018-09-14           2.036245e+14         31471.093038         33742.606344
# 2018-09-17           2.094265e+14         35128.684296         34854.254176
# 2018-09-18           2.006348e+14         10189.437390         32916.577887
# ...                           ...                  ...                  ...
# 2020-08-25           8.608028e+14        125273.490429         81831.863468
# 2020-08-26           8.886997e+14         74234.798338         82982.637290
# 2020-08-27           8.850381e+14         91269.616085         82597.470913
# 2020-08-28           8.763315e+14         39221.138437         82509.579347
# 2020-08-31           9.107695e+14         83956.002289         87453.449690
#
# [485 rows x 34 columns]

# %%
# !pip install pmdarima
# Out:
# Collecting pmdarima
#   Downloading pmdarima-1.8.0-cp37-cp37m-win_amd64.whl (609 kB)
# Requirement already satisfied: joblib>=0.11 in c:\users\sagar singh rajput\anaconda3\lib\site-packages (from pmdarima) (0.14.1)
# Requirement already satisfied: pandas>=0.19 in c:\users\sagar singh rajput\anaconda3\lib\site-packages (from pmdarima) (1.0.1)
# Requirement already satisfied: scikit-learn>=0.22 in c:\users\sagar singh rajput\anaconda3\lib\site-packages (from pmdarima) (0.22.1)
# Requirement already satisfied: statsmodels!=0.12.0,>=0.11 in c:\users\sagar singh rajput\anaconda3\lib\site-packages (from pmdarima) (0.11.0)
# Requirement already satisfied: scipy>=1.3.2 in c:\users\sagar singh rajput\anaconda3\lib\site-packages (from pmdarima) (1.4.1)
# Requirement already satisfied: numpy>=1.17.3 in c:\users\sagar singh rajput\anaconda3\lib\site-packages (from pmdarima) (1.18.1)
# Requirement already satisfied: urllib3 in c:\users\sagar singh rajput\anaconda3\lib\site-packages (from pmdarima) (1.25.8)
# Requirement already satisfied: Cython<0.29.18,>=0.29 in c:\users\sagar singh rajput\anaconda3\lib\site-packages (from pmdarima) (0.29.15)
# Requirement already satisfied: setuptools!=50.0.0,>=38.6.0 in c:\users\sagar singh rajput\anaconda3\lib\site-packages (from pmdarima) (45.2.0.post20200210)
# Requirement already satisfied: python-dateutil>=2.6.1 in c:\users\sagar singh rajput\anaconda3\lib\site-packages (from pandas>=0.19->pmdarima) (2.8.1)
# Requirement already satisfied: pytz>=2017.2 in c:\users\sagar singh rajput\anaconda3\lib\site-packages (from pandas>=0.19->pmdarima) (2019.3)
# Requirement already satisfied: patsy>=0.5 in c:\users\sagar singh rajput\anaconda3\lib\site-packages (from statsmodels!=0.12.0,>=0.11->pmdarima) (0.5.1)
# Requirement already satisfied: six>=1.5 in c:\users\sagar singh rajput\anaconda3\lib\site-packages (from python-dateutil>=2.6.1->pandas>=0.19->pmdarima) (1.14.0)
# Installing collected packages: pmdarima
# Successfully installed pmdarima-1.8.0

# %%
 from pmdarima import auto_arima

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
model=auto_arima(y=training_data['VWAP'],exogenous=training_data[ind_features],trace=True)
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(2,0,2)(0,0,0)[0] intercept   : AIC=20931.540, Time=12.34 sec
#  ARIMA(0,0,0)(0,0,0)[0] intercept   : AIC=20925.228, Time=6.15 sec
#  ARIMA(1,0,0)(0,0,0)[0] intercept   : AIC=20926.352, Time=6.09 sec
#  ARIMA(0,0,1)(0,0,0)[0] intercept   : AIC=20926.323, Time=9.86 sec
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=32616.913, Time=5.56 sec
#  ARIMA(1,0,1)(0,0,0)[0] intercept   : AIC=20929.237, Time=10.56 sec
#
# Best model:  ARIMA(0,0,0)(0,0,0)[0] intercept
# Total fit time: 50.580 seconds

# %%
model.fit(training_data['VWAP'],training_data[ind_features])
# Out:
# ARIMA(maxiter=50, method='lbfgs', order=(0, 0, 0), out_of_sample_size=0,
#       scoring='mse', scoring_args={}, seasonal_order=(0, 0, 0, 0),
#       start_params=None, suppress_warnings=True, trend=None,
#       with_intercept=True)

# %%
forecast=model.predict(n_periods=len(test_data),exogenous=test_data[ind_features])

# %%
test_data['Forecast_ARIMA']=forecast

# %%
test_data[['VWAP','Forecast_ARIMA']].plot(figsize=(15,7))

# %%
from sklearn.metrics import mean_absolute_error,mean_squared_error

# %%
np.sqrt(mean_squared_error(test_data['VWAP'],test_data['FORECAST_ARIMA']))
# Out:
# 187.80015440124652

# %%
mean_absolute_error(test_data['VWAP'],test_data['FORECAST_ARIMA'])
# Out:
# 124.6658216958968
